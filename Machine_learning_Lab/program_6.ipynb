# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # load data

# %%
data = pd.read_csv(r'C:\Users\sempa\Documents\College_Notes\6TH SEM\Lab\Data\playtennis.csv')

# %%
display(data)
# Out:
#     Day   Outlook Temperature Humidity    Wind PlayTennis
# 0    D1     Sunny         Hot     High    Weak         No
# 1    D2     Sunny         Hot     High  Strong         No
# 2    D3  Overcast         Hot     High    Weak        Yes
# 3    D4      Rain        Mild     High    Weak        Yes
# 4    D5      Rain        Cool   Normal    Weak        Yes
# 5    D6      Rain        Cool   Normal  Strong         No
# 6    D7  Overcast        Cool   Normal  Strong        Yes
# 7    D8     Sunny        Mild     High    Weak         No
# 8    D9     Sunny        Cool   Normal    Weak        Yes
# 9   D10      Rain        Mild   Normal    Weak        Yes
# 10  D11     Sunny        Mild   Normal  Strong        Yes
# 11  D12  Overcast        Mild     High  Strong        Yes
# 12  D13  Overcast         Hot   Normal    Weak        Yes
# 13  D14      Rain        Mild     High  Strong         No

# %%
#drop irrelavent data
data.drop('Day',axis=1,inplace=True)

# %%
display(data)
# Out:
#      Outlook Temperature Humidity    Wind PlayTennis
# 0      Sunny         Hot     High    Weak         No
# 1      Sunny         Hot     High  Strong         No
# 2   Overcast         Hot     High    Weak        Yes
# 3       Rain        Mild     High    Weak        Yes
# 4       Rain        Cool   Normal    Weak        Yes
# 5       Rain        Cool   Normal  Strong         No
# 6   Overcast        Cool   Normal  Strong        Yes
# 7      Sunny        Mild     High    Weak         No
# 8      Sunny        Cool   Normal    Weak        Yes
# 9       Rain        Mild   Normal    Weak        Yes
# 10     Sunny        Mild   Normal  Strong        Yes
# 11  Overcast        Mild     High  Strong        Yes
# 12  Overcast         Hot   Normal    Weak        Yes
# 13      Rain        Mild     High  Strong         No

# %%
def naive_bayes_predict(data, target_name, test_instance):
    target_value_counts = data[target_name].value_counts().to_dict()
    proba_target_value_s = (data[target_name].value_counts() / data.shape[0]).to_dict()
    predicted_target_values = {}

    for target, value_count in target_value_counts.items():
        given_target_prob = 1.0
        data_subset = data[data[target_name] == target]

        for attrib, value in test_instance.items():
            conditional_prob = data_subset[data_subset[attrib] == value].shape[0] / data_subset.shape[0]
            given_target_prob *= conditional_prob

        proba_target_value = proba_target_value_s[target] * given_target_prob
        predicted_target_values[target] = proba_target_value

    return predicted_target_values

# %%
# Creates a test instance
test_instance = {"Outlook": "Sunny", "Temperature": "Cool", "Humidity": "High", "Wind": "Strong"}

# %%
# Performs prediction
prediction = naive_bayes_predict(data.copy(), "PlayTennis", test_instance)
print(prediction)
# Out:
# {'Yes': 0.005291005291005291, 'No': 0.02057142857142857}
